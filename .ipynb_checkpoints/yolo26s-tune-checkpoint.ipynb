# %%
import os
from collections import defaultdict
from pathlib import Path
import glob


dataset_path = Path(r"C:\Users\zhou\Desktop\yolo26s-tune")
train_images_dir = dataset_path / "train" / "images"
train_labels_dir = dataset_path / "train" / "labels"
val_images_dir = dataset_path / "valid" / "images"
val_labels_dir = dataset_path / "valid" / "labels"

class_names = {
    0: "crazing",
    1: "inclusion",
    2: "patches",
    3: "pitted_surface",
    4: "rolled-in_scale",
    5: "scratches"
}

# ================== 统计函数 ==================
def count_dataset(split_name, images_dir, labels_dir):
    print(f"\n=== {split_name} 数据集概况 ===")
    
    # 统计图片
    image_files = glob.glob(str(images_dir / "*.jpg")) + \
                  glob.glob(str(images_dir / "*.jpeg")) + \
                  glob.glob(str(images_dir / "*.png"))
    
    # 统计标签
    label_files = glob.glob(str(labels_dir / "*.txt"))
    
    print(f"图片数量: {len(image_files)}")
    print(f"标签文件数量: {len(label_files)}")
    print(f"有标签但无图片的数量: {len(label_files) - len(image_files) if len(label_files) > len(image_files) else 0}")
    
    # 统计每个类别的目标数量
    class_count = defaultdict(int)
    empty_label_count = 0
    total_objects = 0
    
    for label_path in label_files:
        with open(label_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            if not lines:
                empty_label_count += 1
                continue
            for line in lines:
                if line.strip():
                    cls_id = int(line.strip().split()[0])
                    class_count[cls_id] += 1
                    total_objects += 1
    
    print(f"总目标框数量: {total_objects}")
    print(f"空标签文件数量（无缺陷）: {empty_label_count}")
    
    print("\n各类别目标数量：")
    for cls_id in range(6):
        count = class_count[cls_id]
        name = class_names[cls_id]
        print(f"  {cls_id:1d} - {name:15s}: {count:6d} 个目标框")
    
    # 简单图片尺寸统计
    sizes = []
    for img_path in image_files[:50]:   
        try:
            from PIL import Image
            with Image.open(img_path) as img:
                sizes.append(img.size)
        except:
            pass
    
    if sizes:
        widths = [w for w, h in sizes]
        heights = [h for w, h in sizes]
        print(f"\n图片尺寸范围: {min(widths)}×{min(heights)} ~ {max(widths)}×{max(heights)}")
        print(f"平均尺寸: {sum(widths)/len(widths):.0f}×{sum(heights)/len(heights):.0f}")

# ================== 执行统计 ==================
print("=== NEU-DET 钢材表面缺陷数据集概况 ===")
print(f"数据集根目录: {dataset_path}\n")

count_dataset("训练集 (train)", train_images_dir, train_labels_dir)
count_dataset("验证集 (valid)", val_images_dir, val_labels_dir)
# Out:
# === NEU-DET 钢材表面缺陷数据集概况 ===
# 数据集根目录: C:\Users\zhou\Desktop\project\yolo26-Steel-Surface-Defect-Detection\dataset
#
#
# === 训练集 (train) 数据集概况 ===
# 图片数量: 1770
# 标签文件数量: 1770
# 有标签但无图片的数量: 0
# 总目标框数量: 4125
# 空标签文件数量（无缺陷）: 0
#
# 各类别目标数量：
#   0 - crazing        :    681 个目标框
#   1 - inclusion      :    996 个目标框
#   2 - patches        :    864 个目标框
#   3 - pitted_surface :    424 个目标框
#   4 - rolled-in_scale:    619 个目标框
#   5 - scratches      :    541 个目标框
#
# 图片尺寸范围: 200×200 ~ 200×200
# 平均尺寸: 200×200
#
# === 验证集 (valid) 数据集概况 ===
# 图片数量: 30
# 标签文件数量: 30
# 有标签但无图片的数量: 0
# 总目标框数量: 64
# 空标签文件数量（无缺陷）: 0
#
# 各类别目标数量：
#   0 - crazing        :      8 个目标框
#   1 - inclusion      :     15 个目标框
#   2 - patches        :     17 个目标框
#   3 - pitted_surface :      8 个目标框
#   4 - rolled-in_scale:      9 个目标框
#   5 - scratches      :      7 个目标框
#
# 图片尺寸范围: 200×200 ~ 200×200
# 平均尺寸: 200×200
#
# === 总体总结 ===
# 类别总数: 6 类
# ...

# %%
import torch
print("PyTorch 版本:", torch.__version__)
print("CUDA 是否可用:", torch.cuda.is_available())
print("GPU 数量:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("当前 GPU 名称:", torch.cuda.get_device_name(0))
# Out:
# PyTorch 版本: 2.5.1
# CUDA 是否可用: True
# GPU 数量: 1
# 当前 GPU 名称: NVIDIA GeForce RTX 3080 Ti Laptop GPU

# %%
from ultralytics import YOLO
import os

# 1. 加载模型
model = YOLO("yolo26s.pt") 

# 2. dataset 绝对路径
dataset_path = Path(r"C:\Users\zhou\Desktop\yolo26s-tune")
yaml_path = Path(r"C:\Users\zhou\Desktop\yolo26s-tune\dataset\data.yaml")

# 3. 开始自动调参
results = model.tune(
    data=yaml_path,           
    epochs=20,                # 每个候选超参数训练 20 个 epoch
    iterations=150,           # 总共尝试 150 组超参数（平衡时间与效果）
    optimizer="AdamW",        # 小数据集推荐 AdamW，收敛更快
    imgsz=640,
    batch=16,                 
    patience=10,              # 每个 trial 的早停
    plots=False,              # 关闭绘图
    save=False,               # 关闭中间模型保存，节省磁盘
    val=True,                 # 仅在最后一次 epoch 验证（默认只验证最终）
    device=0,
    name="neu_det_tune",      # 结果文件夹名
    exist_ok=True
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=C:\Users\zhou\Desktop\project\yolo26-Steel-Surface-Defect-Detection\runs\detect\neu_det_tune3'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/150 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0, 'close_mosaic': 10}
# Saved C:\Users\zhou\Desktop\project\yolo26-Steel-Surface-Defect-Detection\runs\detect\neu_det_tune3\tune_scatter_plots.png
# Saved C:\Users\zhou\Desktop\project\yolo26-Steel-Surface-Defect-Detection\runs\detect\neu_det_tune3\tune_fitness.png
#
# Tuner: 1/150 iterations complete  (716.67s)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo26s.pt")  

best_yaml = r"C:\Users\zhou\Desktop\yolo26s-tune\runs\detect\neu_det_tune3\best_hyperparameters.yaml"

results = model.train(
    data=r"C:\Users\zhou\Desktop\yolo26s-tune\dataset\data.yaml", 
    epochs=500,
    imgsz=640,
    batch=16,                    
    device=0,
    patience=50,
    plots=True,
    exist_ok=True,
    cfg=best_yaml,                
    optimizer="AdamW"      
)
# Out:
# C:\Users\zhou\anaconda3\envs\NEU-DET\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# New https://pypi.org/project/ultralytics/8.4.37 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.36  Python-3.11.15 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16384MiB)
# ...

# %%
# 验证
model.val()
# Out:
# Ultralytics 8.4.36  Python-3.11.15 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16384MiB)
# YOLO26s summary (fused): 122 layers, 9,467,502 parameters, 0 gradients, 20.5 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 54.627.7 MB/s, size: 11.4 KB)
# val: Scanning C:\Users\zhou\Desktop\project\yolo26-Steel-Surface-Defect-Detection\dataset\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.6s/it 3.3s<10.0s
#                    all         30         64      0.759      0.844      0.832      0.486
#                crazing          5          8      0.584      0.625      0.598      0.315
#              inclusion          5         15      0.576      0.933      0.848      0.443
#                patches          5         17       0.94       0.92      0.986      0.663
# ...
